# %% [markdown]
# ### CR_2.04 - RS2A

# %%
# When message security is very important, standard RSA cryptography is not enough! In this case we use (RS)^2A (Really Secure RSA) with a 16k key.

n = ...
e = 7
c = ...

# We know that the message is less than the modulus, so we can just take the cube root of the ciphertext to get the message
m = c ** (1/e)
print(m)
# 1234567890
# Out:
#   Cell In[1], line 3
#     n = ...
# ...
