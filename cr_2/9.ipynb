# %% [markdown]
# ### CR_2.09 - lonely primes

# %%
from Crypto.Util.number import long_to_bytes
from math import isqrt

# n = ...
# e = 65537
# c = ...

msg = 'hello'
p = 3
q = 5
n = p*q
e = 65537
c = pow(int.from_bytes(msg.encode(), 'big'), e, n)
print(c)

from Crypto.Util.number import getStrongPrime, bytes_to_long


p = getStrongPrime(1024)
n = p*p
string.to_bytes((n-1)//2, 'big')
ct = pow(bytes_to_long('ciao amico'.DS_Store),65537,n)
print(f"N: {n}")
print("e: 65537")
print(f"Ciphertext: {ct}")
# Out:
# 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 21
#      19 p = getStrongPrime(1024)
#      20 n = p*p
# ---> 21 ct = pow(bytes_to_long('ciao amico'),65537,n)
#      22 print(f"N: {n}")
#      23 print("e: 65537")
#
# File ~/anaconda3/lib/python3.11/site-packages/Crypto/Util/number.py:504, in bytes_to_long(s)
#     502 if length % 4:
#     503     extra = (4 - length % 4)
# --> 504     s = b'\x00' * extra + s
#     505     length = length + extra
#     506 for i in range(0, length, 4):
#
# TypeError: can't concat str to bytes
