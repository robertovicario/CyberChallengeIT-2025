# %% [markdown]
# ### CR_2.05 - Oracle - Level 2

# %%
from Crypto.Util.number import long_to_bytes
from gmpy2 import *
from pwn import *

# encrypt(x)**2 - encrypt(x**2) is multiple of 'n'.
# e = 65537
# c = flag_encrypted
# n = ?
HOST = "oracle.challs.cyberchallenge.it"
PORT = 9042
r = remote(HOST, PORT)

r.recvuntil('flag: ')
flag_encrypted = r.recvline().decode()[0:-1]

r.recvuntil('> ')
r.sendline(str(1).encode())

r.recvuntil('Plaintext > ')
r.sendline(str(109).encode())

r.recvuntil('Encrypted: ')
two_encrypted = int(r.recvline().decode()[0:-1])

encrypt_x_2 = two_encrypted ** 2

r.recvuntil('> ')
r.sendline(str(1).encode())

r.recvuntil('Plaintext > ')
r.sendline(str(11881).encode())

r.recvuntil('Encrypted: ')
encrypt_x2 = int(r.recvline().decode()[0:-1])

multiple_n1 = encrypt_x_2 - encrypt_x2

r.recvuntil('> ')
r.sendline(str(1).encode())

r.recvuntil('Plaintext > ')
r.sendline(str(167).encode())

r.recvuntil('Encrypted: ')
three_encrypted = int(r.recvline().decode()[0:-1])

encrypt_x_3 = three_encrypted ** 2

r.recvuntil('> ')
r.sendline(str(1).encode())

r.recvuntil('Plaintext > ')
r.sendline(str(27889).encode())

r.recvuntil('Encrypted: ')
encrypt_x3 = int(r.recvline().decode()[0:-1])

multiple_n2 = encrypt_x_3 - encrypt_x3

r.recvuntil('> ')
r.sendline(str(1).encode())

r.recvuntil('Plaintext > ')
r.sendline(str(101).encode())

r.recvuntil('Encrypted: ')
seven_encrypted = int(r.recvline().decode()[0:-1])

encrypt_x_7 = seven_encrypted ** 2

r.recvuntil('> ')
r.sendline(str(1).encode())

r.recvuntil('Plaintext > ')
r.sendline(str(10201).encode())

r.recvuntil('Encrypted: ')
encrypt_x7 = int(r.recvline().decode()[0:-1])

multiple_n3 = encrypt_x_7 - encrypt_x7

n_ = gcd(multiple_n2, multiple_n3)
n = int(gcd(n_, multiple_n1))

if int(flag_encrypted[-1]) % 2 != 0:
    print('Repeat.')

get_context().precision = 65536
flag = mul(int(flag_encrypted), 0.5)

r.recvuntil('> ')
r.sendline(str(2).encode())

r.recvuntil('Ciphertext > ')
r.sendline(str(int(flag)).encode())

r.recvuntil('Decrypted: ')
flag_ = int(r.recvline().decode()[0:-1])

r.recvuntil('> ')
r.sendline(str(2).encode())

r.recvuntil('Ciphertext > ')
r.sendline(str(2).encode())

r.recvuntil('Decrypted: ')
p_decrypt = int(r.recvline().decode()[0:-1])

flags = p_decrypt * flag_

long_to_bytes(pow(flags, 1, n)).decode()
# Out:
# [x] Opening connection to oracle.challs.cyberchallenge.it on port 9042
# [x] Opening connection to oracle.challs.cyberchallenge.it on port 9042: Trying 5.75.221.48
# [+] Opening connection to oracle.challs.cyberchallenge.it on port 9042: Done
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:13: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('flag: ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:16: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('> ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:19: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Plaintext > ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:22: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Encrypted: ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:27: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('> ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:30: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Plaintext > ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:33: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Encrypted: ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:38: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('> ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:41: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Plaintext > ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:44: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Encrypted: ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:49: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('> ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:52: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Plaintext > ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:55: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Encrypted: ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:60: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('> ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:63: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Plaintext > ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:66: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Encrypted: ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:71: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('> ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:74: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Plaintext > ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:77: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Encrypted: ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:91: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('> ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:94: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Ciphertext > ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:97: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Decrypted: ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:100: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('> ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:103: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Ciphertext > ')
# /var/folders/3n/vf15kv6n675_m6mzk8p8rfxr0000gn/T/ipykernel_18823/1130340550.py:106: BytesWarning: Text is not bytes; assuming ASCII, no guarantees. See https://docs.pwntools.com/#bytes
#   r.recvuntil('Decrypted: ')
# 'CCIT{3ncrypt&d3crypt}'
