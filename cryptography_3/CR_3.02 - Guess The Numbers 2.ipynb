# %% [markdown]
# ### CR_3.02 - Guess The Numbers 2

# %%
m2 = 2115495185
n2 = 2147483647
v0 = 1680462708
v1 = 77243019
c2 = (v1 - m2 * v0) % n2

def generate_sequence(m, c, n, v0, count=50):
    sequence = [v0, v1]
    current_value = v1
    
    for _ in range(count):
        next_value = (m * current_value + c) % n
        sequence.append(next_value)
        current_value = next_value
    
    return sequence

generate_sequence(m2, c2, n2, v0, count=50)
# Out:
# [1680462708,
#  77243019,
#  608578350,
#  1337708801,
#  1520860970,
#  1618397704,
#  435189838,
#  448415272,
#  2023866352,
#  40509887,
#  526055991,
#  474426967,
#  510604470,
#  1735616855,
#  1144238660,
#  2126921282,
#  1262547222,
#  1470734091,
#  292925842,
#  1267627726,
#  1229026909,
#  374611833,
#  758137603,
#  1367607456,
#  1438504868,
#  1766382755,
#  421907314,
#  1880643469,
#  1671154034,
#  159269387,
#  1851931990,
#  1919960372,
#  1096348280,
#  2055874687,
#  1360732247,
#  705086862,
#  535338047,
#  1457757903,
#  1475540068,
#  687093551,
#  1723512201,
#  1927317532,
#  1743618737,
#  411773694,
#  289904906,
#  1747436805,
#  126098109,
#  430456315,
#  1644560575,
#  1314853335,
#  1918873112,
#  226395588]

# %% [markdown]
# ```txt
# Cryptography is just guessing... change my mind
# Guess me the next 50 numbers of the sequence!
# m = 2115495185
# n = 2147483647
# v[0] = 1680462708
# v[1] = 77243019
# v[2] = 608578350
# v[3] = 1337708801
# v[4] = 1520860970
# v[5] = 1618397704
# v[6] = 435189838
# v[7] = 448415272
# v[8] = 2023866352
# v[9] = 40509887
# v[10] = 526055991
# v[11] = 474426967
# v[12] = 510604470
# v[13] = 1735616855
# v[14] = 1144238660
# v[15] = 2126921282
# v[16] = 1262547222
# v[17] = 1470734091
# v[18] = 292925842
# v[19] = 1267627726
# v[20] = 1229026909
# v[21] = 374611833
# v[22] = 758137603
# v[23] = 1367607456
# v[24] = 1438504868
# v[25] = 1766382755
# v[26] = 421907314
# v[27] = 1880643469
# v[28] = 1671154034
# v[29] = 159269387
# v[30] = 1851931990
# v[31] = 1919960372
# v[32] = 1096348280
# v[33] = 2055874687
# v[34] = 1360732247
# v[35] = 705086862
# v[36] = 535338047
# v[37] = 1457757903
# v[38] = 1475540068
# v[39] = 687093551
# v[40] = 1723512201
# v[41] = 1927317532
# v[42] = 1743618737
# v[43] = 411773694
# v[44] = 289904906
# v[45] = 1747436805
# v[46] = 126098109
# v[47] = 430456315
# v[48] = 1644560575
# v[49] = 1314853335
# v[50] = 1918873112
# v[51] = 226395588
# Here's your flag: CCIT{fun_st4rts_h3r3}
# ```
